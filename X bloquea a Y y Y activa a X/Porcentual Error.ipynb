# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
err_porc_gen_1_C_10 = np.array([25.3933,22.3112,17.7088,13.5390,6.8071,1.6412,4.1218,\
                                10.3441,16.8555,25.0907,33.1869,44.3256,52.0851,62.6761])

err_porc_gen_2_C_10 = np.array([23.7294,20.5905,16.3522,12.4014,7.3574,2.2182,3.5938,\
                                8.5571,14.7895,20.3579,27.4585,35.3039,41.9220,49.9060])

gen_1_std = np.array([1.0137,1.0220,0.4142,0.2497,0.9566,0.5169,0.4440,1.0044,1.4839,1.4152,1.9996,2.0531,2.9332,3.9272])
gen_2_std = np.array([0.8976,0.2793,0.8289,0.5972,0.7466,0.1477,1.0447,1.2320,1.4557,1.0522,0.8140,1.8377,1.0391,0.7548])

coef_hill = np.array([1,1.2,1.4,1.6,1.8,2,2.2,2.4,2.6,2.8,3,3.2,3.4,3.6])

# %%
plt.style.use('seaborn-whitegrid')
plt.errorbar(coef_hill, err_porc_gen_1_C_10, yerr=gen_1_std);
plt.errorbar(coef_hill, err_porc_gen_2_C_10, yerr=gen_2_std);
plt.xlabel("Coeficiente de Hill")
plt.xticks(np.arange(1,3.8,0.2));
plt.ylabel("Error porcentual")
plt.yticks(np.arange(0,70,5));
plt.legend(["Gen 1", "Gen 2"], loc ="lower right")
